# %%
import requests

# %%
us_projects = 'http://127.0.0.1:5000/graphql?query=query%20fundersList%20%7B%0A%09funder(code%3A%20%22US%22)%20%7B%0A%20%20%20%20projects%20%7B%0A%20%20%20%20%20%20projectId%0A%20%20%20%20%20%20projectName%0A%20%20%20%20%20%20funderRef%0A%20%20%20%20%20%20donorSector%0A%20%20%20%20%20%20donorCode%0A%20%20%20%20%20%20donorName%0A%20%20%20%20%20%20recipientCountry%0A%20%20%20%20%20%20recipientSector%0A%20%20%20%20%20%20recipientName%0A%20%20%20%20%20%20totalCommitted%0A%20%20%20%20%20%20totalSpent%0A%20%20%20%20%20%20totalCurrency%0A%20%20%20%20%20%20source%0A%20%20%20%20%20%20donorAmountUnspec%0A%20%20%20%20%20%20recipientAmountUnspec%0A%20%20%20%20%7D%0A%20%20%7D%20%0A%7D&operationName=fundersList'

us_json = requests.get(us_projects).json()['data']['funder']['projects']

# %%
us_json
# Out:
# [{'projectId': 'proj.24497',
#   'projectName': 'Livestock Activity',
#   'funderRef': 'US-18',
#   'donorSector': 'Government',
#   'donorCode': 'US',
#   'donorName': 'Millennium Challenge Corporation',
#   'recipientCountry': 'NE',
#   'recipientSector': 'Country',
#   'recipientName': 'Niger',
#   'totalCommitted': 43200000.0,
#   'totalSpent': 0.0,
#   'totalCurrency': 'USD',
#   'source': 'IATI via D-Portal',
#   'donorAmountUnspec': False,
#   'recipientAmountUnspec': False},
#  {'projectId': 'proj.24620',
#   'projectName': 'Malaria',
#   'funderRef': 'US-GOV-1',
#   'donorSector': 'Government',
#   'donorCode': 'US',
#   'donorName': 'United States Agency for International Development (USAID)',
#   'recipientCountry': 'Not reported',
#   'recipientSector': 'Not reported',
#   'recipientName': 'Not reported',
#   'totalCommitted': 268.7,
#   'totalSpent': 268.7,
#   'totalCurrency': 'USD',
#   'source': 'IATI via D-Portal',
#   'donorAmountUnspec': False,
# ...
